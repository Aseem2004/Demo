# %% [markdown]
# <a href="https://colab.research.google.com/github/Aseem2004/Demo/blob/main/Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step - 1 (Importing the Library)
import pandas as pd

# %%
#Step - 2 (Import Data)
salary=pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/Salary%20Data.csv")

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.shape
# Out:
# (40, 2)

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
 #Step - 3 (Defining dependent (y) and independent (x) variables)
 #Here there are 2 columns, salary and work experience, so clearly salary depends on exp. years and not the other way round i.e. x=exp. years and y=salary
 y=salary["Salary"]
 x=salary[["Experience Years"]]

# %%
x.shape
# It is a column vector
# Out:
# (40, 1)

# %%
y.shape
# It is a flat vector
# Out:
# (40,)

# %%
#Step - 4 (Train Test Split from sklearn)
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)
# train_size return % of values in train dataframe and rest in test.

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
#It splits the dataframe in 4 parts. Initialy had 40 columns, but now it's 30+10.
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %% [markdown]
# By using random_state we are able to fix the random variables. Also, if all 4 parts are defined then also, the variables remain same.
#
# If we are to get better accuracy, then train data should be diverse and covering the extremes.

# %%
x_train
# Out:
#     Experience Years
# 13               3.8
# 31               7.9
# 34               8.7
# 8                3.0
# 17               4.1
# 24               5.5
# 0                1.1
# 33               8.5
# 5                2.2
# 11               3.5
# 1                1.2
# 29               6.8
# 21               4.9
# 2                1.3
# 30               7.1
# 36               9.5
# 3                1.5
# 35               9.0
# 23               5.3
# 32               8.2
# 10               3.2
# 22               5.1
# 18               4.3
# 20               4.7
# 7                2.9
# 14               3.9
# 28               6.5
# 38              10.3

# %%
y_train
# Out:
# 13     60200
# 31    101302
# 34    109431
# 8      60150
# 17     57081
# 24     82200
# 0      39343
# 33    111620
# 5      39891
# 11     60000
# 1      42774
# 29     91738
# 21     67938
# 2      46205
# 30     98273
# 36    116969
# 3      37731
# 35    105582
# 23     83088
# 32    113812
# 10     64445
# 22     66029
# 18     59095
# 20     64500
# 7      56642
# 14     63218
# 28     90000
# 38    122391
# Name: Salary, dtype: int64

# %%
x_test
# Out:
#     Experience Years
# 19               4.5
# 16               4.0
# 15               4.0
# 26               6.0
# 4                2.0
# 12               3.7
# 37               9.6
# 27               6.2
# 39              10.5
# 6                2.5
# 25               5.9
# 9                3.2

# %%
y_test
# Out:
# 19     61111
# 16     56957
# 15     55794
# 26     93940
# 4      43525
# 12     57189
# 37    112635
# 27     91000
# 39    121872
# 6      48266
# 25     81363
# 9      54445
# Name: Salary, dtype: int64

# %%
#Step - 5 (Select model for Linear Regression)
# Clearly, there must be some error. For selecting the Best Fit Line, we calculate squares of errors and add them. The line giving the minimum value is selected as the bets fit line.
# Error= y(actual)-y(predicted), below the line it is -ve and above the line it is +ve
# Best fit line will have the equation of type y=c+mx+error
# Here we are specifically using Linear Regression technique. We could have used others as well.

from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#Step - 6 (To train the model/ Fit model)
# Here the actual machine learning starts, we prepared the data and here we train it
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 26767.86524944281

# %%
model.coef_
# Out:
# array([9459.35953483])

# %% [markdown]
# The intercept is c=26767.86524944281 and coefficient is the slope m=9459.35953483. So, equation of line is salary=c+m(Exp years)+very small error.
# We can now easily calculate salary based on years of experience from this formula and we successfully predicted the values.

# %%
#Step - 7 (Prediction)
model.predict(x_test)

# Here x_test values are put in formula and the model gives a prediction according to it.
# Out:
# array([ 69334.98315618,  64605.30338877,  64605.30338877,  83524.02245843,
#         45686.5843191 ,  61767.49552832, 117577.71678382,  85415.89436539,
#        126091.14036516,  50416.26408652,  82578.08650494,  57037.8157609 ])
